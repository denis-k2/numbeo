# %% [markdown]
# # Extract. Transform. Analysis.

# %%
import pandas as pd
#import numpy as np
import requests
import country_converter as coco
from bs4 import BeautifulSoup
import folium

# %% [markdown]
# ### Extract

# %% [markdown]
# За основу беру текущий индекс Numbeo "Current Cost of Living Index", в котором на данный момент 506 городов и, пока, не понятно сколько стран.

# %%
url = 'https://www.numbeo.com/cost-of-living/rankings_current.jsp'

# %%
df = pd.read_html(url)[1]

# %%
df.head()
# Out:
#    Rank                 City  Cost of Living Index  Rent Index  \
# 0   NaN    Hamilton, Bermuda                161.36      102.29
# 1   NaN  Zurich, Switzerland                120.28       61.53
# 2   NaN   Basel, Switzerland                119.82       45.46
# 3   NaN     Zug, Switzerland                118.68       64.27
# 4   NaN    Bern, Switzerland                112.70       36.46
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                          133.41           167.32                  147.19
# 1                           92.49           122.67                  114.61
# 2                           84.64           125.54                  114.14
# 3                           92.94           120.79                  118.36
# 4                           76.63           114.77                  105.62
#
#    Local Purchasing Power Index
# 0                         88.42
# 1                        115.32
# 2                        109.13
# 3                        136.38
# 4                        116.10

# %% [markdown]
# Добавляю в таблицу ссылки на страницы данных городов

# %%
response = requests.get(url).text
soup = BeautifulSoup(response, 'lxml')
links = soup.find_all('td', class_='cityOrCountryInIndicesTable')

href_list = []
for i in links:
    href_list.append([i.find('a').text, i.find('a').get('href')])
    
city_link = pd.DataFrame(href_list, columns=['City', 'link'])

df = df.merge(city_link, on='City', how='left')

# %% [markdown]
# ### Transform

# %%
df.drop('Rank', axis=1, inplace=True)

# %%
df.head()
# Out:
#                   City  Cost of Living Index  Rent Index  \
# 0    Hamilton, Bermuda                161.36      102.29
# 1  Zurich, Switzerland                120.28       61.53
# 2   Basel, Switzerland                119.82       45.46
# 3     Zug, Switzerland                118.68       64.27
# 4    Bern, Switzerland                112.70       36.46
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                          133.41           167.32                  147.19
# 1                           92.49           122.67                  114.61
# 2                           84.64           125.54                  114.14
# 3                           92.94           120.79                  118.36
# 4                           76.63           114.77                  105.62
#
#    Local Purchasing Power Index  \
# 0                         88.42
# 1                        115.32
# 2                        109.13
# 3                        136.38
# 4                        116.10
#
#                                                 link
# 0  https://www.numbeo.com/cost-of-living/in/Hamil...
# 1    https://www.numbeo.com/cost-of-living/in/Zurich
# 2     https://www.numbeo.com/cost-of-living/in/Basel
# 3       https://www.numbeo.com/cost-of-living/in/Zug
# 4      https://www.numbeo.com/cost-of-living/in/Bern

# %% [markdown]
# #### Разделить Город - Штат - Страна

# %%
split_table1 = df['City'].str.rsplit(', ', n=1, expand=True)
split_table1.columns=['city_state', 'country']

split_table2 = split_table1['city_state'].str.split(', ', n=1, expand=True)
split_table2.columns=['city', 'state']

# %%
split_table2
# Out:
#            city state
# 0      Hamilton  None
# 1        Zurich  None
# 2         Basel  None
# 3           Zug  None
# 4          Bern  None
# ..          ...   ...
# 502   Islamabad  None
# 503      Lahore  None
# 504     Karachi  None
# 505  Rawalpindi  None
# 506    Peshawar  None
#
# [507 rows x 2 columns]

# %%
df = pd.concat([split_table2, split_table1['country'], df],axis=1)

# %%
df.head()
# Out:
#        city state      country                 City  Cost of Living Index  \
# 0  Hamilton  None      Bermuda    Hamilton, Bermuda                161.36
# 1    Zurich  None  Switzerland  Zurich, Switzerland                120.28
# 2     Basel  None  Switzerland   Basel, Switzerland                119.82
# 3       Zug  None  Switzerland     Zug, Switzerland                118.68
# 4      Bern  None  Switzerland    Bern, Switzerland                112.70
#
#    Rent Index  Cost of Living Plus Rent Index  Groceries Index  \
# 0      102.29                          133.41           167.32
# 1       61.53                           92.49           122.67
# 2       45.46                           84.64           125.54
# 3       64.27                           92.94           120.79
# 4       36.46                           76.63           114.77
#
#    Restaurant Price Index  Local Purchasing Power Index  \
# 0                  147.19                         88.42
# 1                  114.61                        115.32
# 2                  114.14                        109.13
# 3                  118.36                        136.38
# 4                  105.62                        116.10
#
#                                                 link
# 0  https://www.numbeo.com/cost-of-living/in/Hamil...
# 1    https://www.numbeo.com/cost-of-living/in/Zurich
# 2     https://www.numbeo.com/cost-of-living/in/Basel
# 3       https://www.numbeo.com/cost-of-living/in/Zug
# 4      https://www.numbeo.com/cost-of-living/in/Bern

# %%
df['state'].nunique()
# Out:
# 36

# %%
df['state'].unique()
# Out:
# array([None, 'HI', 'CA', 'NY', 'AK', 'WA', 'DC', 'MA', 'CO', 'OR', 'FL',
#        'TN', 'BC', 'IL', 'NC', 'MN', 'TX', 'LA', 'PA',
#        'Newfoundland and Labrador', 'NE', 'GA', 'MD', 'AZ', 'NV', 'OH',
#        'IN', 'MI', 'WI', 'KY', 'ID', 'MO', 'UT', 'OK', 'AR', 'KS',
#        'Ajara'], dtype=object)

# %%
df[df['state'].notnull() & (df['country'] != "United States")]
# Out:
#            city                      state  country  \
# 53      Nanaimo                         BC   Canada
# 72   St. John's  Newfoundland and Labrador   Canada
# 450      Batumi                      Ajara  Georgia
#
#                                               City  Cost of Living Index  \
# 53                             Nanaimo, BC, Canada                 77.47
# 72   St. John's, Newfoundland and Labrador, Canada                 75.16
# 450                         Batumi, Ajara, Georgia                 32.25
#
#      Rent Index  Cost of Living Plus Rent Index  Groceries Index  \
# 53        37.20                           58.42            81.15
# 72        22.95                           50.46            74.43
# 450       12.79                           23.04            31.50
#
#      Restaurant Price Index  Local Purchasing Power Index  \
# 53                    66.41                         90.51
# 72                    71.00                        141.04
# 450                   27.24                         26.18
#
#                                                   link
# 53    https://www.numbeo.com/cost-of-living/in/Nanaimo
# 72   https://www.numbeo.com/cost-of-living/in/St-Jo...
# 450    https://www.numbeo.com/cost-of-living/in/Batumi

# %% [markdown]
# #### Добавляю alpha_3 код к странам
# Добавляю через lambda к каждой строке. Не самый эффективный вариант, обрабатывается капждая строка, страны дублируются, но просто попробовать (merge уже был).

# %%
df['country_code'] = df.apply(lambda row: coco.convert(names=row.country, to='ISO3') , axis = 1)

# %%
df.head(3)
# Out:
#        city state      country                 City  Cost of Living Index  \
# 0  Hamilton  None      Bermuda    Hamilton, Bermuda                161.36
# 1    Zurich  None  Switzerland  Zurich, Switzerland                120.28
# 2     Basel  None  Switzerland   Basel, Switzerland                119.82
#
#    Rent Index  Cost of Living Plus Rent Index  Groceries Index  \
# 0      102.29                          133.41           167.32
# 1       61.53                           92.49           122.67
# 2       45.46                           84.64           125.54
#
#    Restaurant Price Index  Local Purchasing Power Index  \
# 0                  147.19                         88.42
# 1                  114.61                        115.32
# 2                  114.14                        109.13
#
#                                                 link country_code
# 0  https://www.numbeo.com/cost-of-living/in/Hamil...          BMU
# 1    https://www.numbeo.com/cost-of-living/in/Zurich          CHE
# 2     https://www.numbeo.com/cost-of-living/in/Basel          CHE

# %% [markdown]
# #### Добавляю код к штатам USA

# %% [markdown]
# Сработало! Привел штаты Америки к стандарту

# %%
indexes = df[df['state'].notnull() & (df['country'] != "United States")]['state'].index
df.loc[indexes, 'state'] = None

# %%
df['state'] = df.apply(lambda row: f"US-{row['state']}" if row['state'] != None else None, axis = 1)

# %%
df.head(10)
# Out:
#             city  state        country                              City  \
# 0       Hamilton   None        Bermuda                 Hamilton, Bermuda
# 1         Zurich   None    Switzerland               Zurich, Switzerland
# 2          Basel   None    Switzerland                Basel, Switzerland
# 3            Zug   None    Switzerland                  Zug, Switzerland
# 4           Bern   None    Switzerland                 Bern, Switzerland
# 5       Lausanne   None    Switzerland             Lausanne, Switzerland
# 6         Geneva   None    Switzerland               Geneva, Switzerland
# 7       Honolulu  US-HI  United States       Honolulu, HI, United States
# 8         Beirut   None        Lebanon                   Beirut, Lebanon
# 9  Santa Barbara  US-CA  United States  Santa Barbara, CA, United States
#
#    Cost of Living Index  Rent Index  Cost of Living Plus Rent Index  \
# 0                161.36      102.29                          133.41
# 1                120.28       61.53                           92.49
# 2                119.82       45.46                           84.64
# 3                118.68       64.27                           92.94
# 4                112.70       36.46                           76.63
# 5                111.67       53.34                           84.07
# 6                103.97       70.36                           88.07
# 7                101.81       63.28                           83.58
# 8                100.94       24.66                           64.85
# 9                100.05       90.86                           95.70
#
#    Groceries Index  Restaurant Price Index  Local Purchasing Power Index  \
# 0           167.32                  147.19                         88.42
# 1           122.67                  114.61                        115.32
# 2           125.54                  114.14                        109.13
# 3           120.79                  118.36                        136.38
# 4           114.77                  105.62                        116.10
# 5           113.18                  106.24                        111.56
# 6           102.07                  110.93                        111.93
# 7           112.58                   86.98                         93.82
# 8           118.67                   71.87                         14.26
# 9           107.15                   95.94                         69.60
#
#                                                 link country_code
# 0  https://www.numbeo.com/cost-of-living/in/Hamil...          BMU
# 1    https://www.numbeo.com/cost-of-living/in/Zurich          CHE
# 2     https://www.numbeo.com/cost-of-living/in/Basel          CHE
# 3       https://www.numbeo.com/cost-of-living/in/Zug          CHE
# 4      https://www.numbeo.com/cost-of-living/in/Bern          CHE
# 5  https://www.numbeo.com/cost-of-living/in/Lausanne          CHE
# 6    https://www.numbeo.com/cost-of-living/in/Geneva          CHE
# 7  https://www.numbeo.com/cost-of-living/in/Honolulu          USA
# 8    https://www.numbeo.com/cost-of-living/in/Beirut          LBN
# 9  https://www.numbeo.com/cost-of-living/in/Santa...          USA

# %% [markdown]
# Эксперименты с приведение штатов к стандарту. Сработало.

# %%
#df34 = df.copy()
#for i, state in df34['state'].items():
#    if state != None:
#        df34.loc[i, 'state'] = f'US-{state}'

# %% [markdown]
# ### Scraping US-states codes from wiki and transform

# %%
url_states = 'https://en.wikipedia.org/wiki/ISO_3166-2:US'

# %%
df_states = pd.read_html(url_states)[0]

# %%
df_states.head()
# Out:
#     Code Subdivision name (en) Subdivision category
# 0  US-AL               Alabama                State
# 1  US-AK                Alaska                State
# 2  US-AZ               Arizona                State
# 3  US-AR              Arkansas                State
# 4  US-CA            California                State

# %%
df_states.columns = ['state_code', 'state_name', 'category']
df_states.set_index('state_code', inplace=True)

# %%
df_states.head()
# Out:
#             state_name category
# state_code
# US-AL          Alabama    State
# US-AK           Alaska    State
# US-AZ          Arizona    State
# US-AR         Arkansas    State
# US-CA       California    State

# %% [markdown]
# # Карта
# В индексе Numbeo 505 городов, но не понятно, какие страны, много их или мало. Сколько городов в этих странах и в каких пропорциях. Суммарные цифры мне мало что скажут, гораздо понятнее будет отобразить их на карте.

# %%
map_df = df.groupby('country_code')['city'].nunique().reset_index().sort_values('city', ascending=False)
map_df
# Out:
#     country_code  city
# 119          USA    74
# 40           GBR    29
# 18           CAN    28
# 28           DEU    22
# 56           ITA    18
# ..           ...   ...
# 59           JOR     1
# 58           JEY     1
# 57           JAM     1
# 54           ISL     1
# 125          ZWE     1
#
# [126 rows x 2 columns]

# %%
m = folium.Map(location=[37.87820990704326, 6.555063556986549], zoom_start=1.5)
folium.Choropleth(
    geo_data='data/world.geojson',
    name="choropleth",
    data=map_df,
    columns=['country_code', 'city'],
    key_on="feature.properties.ISO_A3", 
    fill_color="YlGn",
    nan_fill_color='pink',
    fill_opacity=0.8,
    bins=7,
    reset=True,
    highlight=True,
    legend_name='Count of cities'
).add_to(m)

# %% [markdown]
# На github интерактивная карта не отображается, поэтому вместо вывода карты, вставил картинку.
#
# Теперь видно какие страны есть в индексе, а каких нет, и сколько городов в каждой стране. Меня всё устраивает, вот только мне не нужно в Индии много городов. Удалю лишние (оставлю 2).

# %% [markdown]
# ![title](map.png)
